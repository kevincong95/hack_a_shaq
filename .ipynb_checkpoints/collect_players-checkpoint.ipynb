# %%
import nbawebstats as nbaws
import pandas as pd

# %%
players = nbaws.request_stats('all-players', {'Season': 2015, 'IsOnlyCurrentSeason': True})

# %%
players = dict(players)['list']

# %%
headers = players[0].keys()

# %%
headers
# Out:
# dict_keys(['TEAM_ID', 'TEAM_CITY', 'GAMES_PLAYED_FLAG', 'TEAM_CODE', 'TO_YEAR', 'TEAM_NAME', 'PLAYERCODE', 'DISPLAY_FIRST_LAST', 'DISPLAY_LAST_COMMA_FIRST', 'PERSON_ID', 'FROM_YEAR', 'TEAM_ABBREVIATION', 'ROSTERSTATUS'])

# %%
import csv

# %%
csvfile = open('players16.csv', 'w')

# %%
writer = csv.DictWriter(csvfile, fieldnames = headers)

# %%
writer.writeheader()

# %%
writer.writerows(players)

# %%
players
# Out:
# [{'DISPLAY_FIRST_LAST': 'Quincy Acy',
#   'DISPLAY_LAST_COMMA_FIRST': 'Acy, Quincy',
#   'FROM_YEAR': '2012',
#   'GAMES_PLAYED_FLAG': 'Y',
#   'PERSON_ID': 203112,
#   'PLAYERCODE': 'quincy_acy',
#   'ROSTERSTATUS': 1,
#   'TEAM_ABBREVIATION': 'SAC',
#   'TEAM_CITY': 'Sacramento',
#   'TEAM_CODE': 'kings',
#   'TEAM_ID': 1610612758,
#   'TEAM_NAME': 'Kings',
#   'TO_YEAR': '2016'},
#  {'DISPLAY_FIRST_LAST': 'Jordan Adams',
#   'DISPLAY_LAST_COMMA_FIRST': 'Adams, Jordan',
#   'FROM_YEAR': '2014',
#   'GAMES_PLAYED_FLAG': 'Y',
#   'PERSON_ID': 203919,
#   'PLAYERCODE': 'jordan_adams',
#   'ROSTERSTATUS': 1,
#   'TEAM_ABBREVIATION': 'MEM',
#   'TEAM_CITY': 'Memphis',
#   'TEAM_CODE': 'grizzlies',
#   'TEAM_ID': 1610612763,
#   'TEAM_NAME': 'Grizzlies',
#   'TO_YEAR': '2016'},
#  {'DISPLAY_FIRST_LAST': 'Steven Adams',
#   'DISPLAY_LAST_COMMA_FIRST': 'Adams, Steven',
#   'FROM_YEAR': '2013',
#   'GAMES_PLAYED_FLAG': 'Y',
#   'PERSON_ID': 203500,
#   'PLAYERCODE': 'steven_adams',
# ...

# %%
players = pd.DataFrame.from_csv('all_players.csv')

# %%
players.head()
# Out:
#                 TEAM_CITY GAMES_PLAYED_FLAG  TEAM_CODE  TO_YEAR  TEAM_NAME  \
# TEAM_ID
# 1610612758     Sacramento                 Y      kings     2016      Kings
# 1610612763        Memphis                 Y  grizzlies     2016  Grizzlies
# 1610612760  Oklahoma City                 Y    thunder     2016    Thunder
# 1610612749      Milwaukee                 Y      bucks     2014      Bucks
# 1610612752       New York                 Y     knicks     2016     Knicks
#
#                PLAYERCODE DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# TEAM_ID
# 1610612758     quincy_acy         Quincy Acy              Acy, Quincy
# 1610612763   jordan_adams       Jordan Adams            Adams, Jordan
# 1610612760   steven_adams       Steven Adams            Adams, Steven
# 1610612749    jeff_adrien        Jeff Adrien             Adrien, Jeff
# 1610612752  arron_afflalo      Arron Afflalo           Afflalo, Arron
#
#             PERSON_ID  FROM_YEAR TEAM_ABBREVIATION  ROSTERSTATUS
# ...

# %%
pbp = nbaws.request_stats('player-career-stats', {'PlayerID': 203083})

# %%
pbp = pd.DataFrame.from_csv('2015-16reg/0021500001.csv')

# %%
pbp.head()
# Out:
#     GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD WCTIMESTRING  \
# 0  21500001         0            12                   0       1      8:12 PM
# 1  21500001         1            10                   0       1      8:12 PM
# 2  21500001         2             2                  42       1      8:13 PM
# 3  21500001         3             4                   0       1      8:13 PM
# 4  21500001         4             5                  45       1      8:13 PM
#
#   PCTIMESTRING                                    HOMEDESCRIPTION  \
# 0        12:00                                                NaN
# 1        12:00    Jump Ball Horford vs. Drummond: Tip to Ilyasova
# 2        11:41                              Horford BLOCK (1 BLK)
# 3        11:39                     Bazemore REBOUND (Off:0 Def:1)
# 4        11:37  Bazemore Out of Bounds - Bad Pass Turnover Tur...
#
#    NEUTRALDESCRIPTION              VISITORDESCRIPTION  \
# ...

# %%
dict(pbp)['season-totals-regular']
# Out:
# [{'AST': 30,
#   'BLK': 95,
#   'DREB': 288,
#   'FG3A': 2,
#   'FG3M': 1,
#   'FG3_PCT': 0.5,
#   'FGA': 342,
#   'FGM': 208,
#   'FG_PCT': 0.608,
#   'FTA': 159,
#   'FTM': 59,
#   'FT_PCT': 0.371,
#   'GP': 60,
#   'GS': 10,
#   'LEAGUE_ID': '00',
#   'MIN': 1243,
#   'OREB': 169,
#   'PF': 144,
#   'PLAYER_AGE': 19.0,
#   'PLAYER_ID': 203083,
#   'PTS': 476,
#   'REB': 457,
#   'SEASON_ID': '2012-13',
#   'STL': 59,
#   'TEAM_ABBREVIATION': 'DET',
#   'TEAM_ID': 1610612765,
#   'TOV': 57},
#  {'AST': 35,
#   'BLK': 131,
#   'DREB': 631,
#   'FG3A': 2,
#   'FG3M': 0,
#   'FG3_PCT': 0.0,
#   'FGA': 769,
#   'FGM': 479,
#   'FG_PCT': 0.623,
#   'FTA': 328,
#   'FTM': 137,
#   'FT_PCT': 0.418,
#   'GP': 81,
#   'GS': 81,
#   'LEAGUE_ID': '00',
#   'MIN': 2619,
#   'OREB': 440,
#   'PF': 273,
#   'PLAYER_AGE': 20.0,
#   'PLAYER_ID': 203083,
#   'PTS': 1095,
#   'REB': 1071,
#   'SEASON_ID': '2013-14',
#   'STL': 101,
#   'TEAM_ABBREVIATION': 'DET',
#   'TEAM_ID': 1610612765,
# ...

# %%
def ft_rate(playerid, season):
    career_stats = nbaws.request_stats('player-career-stats', {'PlayerID': playerid})
    by_season = dict(career_stats)['season-totals-regular']
    for year in by_season:
        if int(year['SEASON_ID'][2:4]) == season:
            return year['FT_PCT']

# %%
ad0 = ft_rate(203083, 15)

# %%
ad0
# Out:
# 0.355

# %%
runthru = pbp.iterrows()

# %%
dir(runthru)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'close',
#  'gi_code',
#  'gi_frame',
#  'gi_running',
#  'send',
#  'throw']

# %%
runthru.__next__()
# Out:
# (1,
#  GAME_ID                                                             21500001
#  EVENTNUM                                                                   1
#  EVENTMSGTYPE                                                              10
#  EVENTMSGACTIONTYPE                                                         0
#  PERIOD                                                                     1
#  WCTIMESTRING                                                         8:12 PM
#  PCTIMESTRING                                                           12:00
#  HOMEDESCRIPTION              Jump Ball Horford vs. Drummond: Tip to Ilyasova
#  NEUTRALDESCRIPTION                                                       NaN
#  VISITORDESCRIPTION                                                       NaN
#  SCORE                                                                    NaN
#  SCOREMARGIN                                                              NaN
# ...

# %%
runthru = pbp.itertuples()

# %%
runthru.__next__()
# Out:
# Pandas(Index=0, GAME_ID=21500001, EVENTNUM=0, EVENTMSGTYPE=12, EVENTMSGACTIONTYPE=0, PERIOD=1, WCTIMESTRING='8:12 PM', PCTIMESTRING='12:00', HOMEDESCRIPTION=nan, NEUTRALDESCRIPTION=nan, VISITORDESCRIPTION=nan, SCORE=nan, SCOREMARGIN=nan, PERSON1TYPE=0.0, PLAYER1_ID=0, PLAYER1_NAME=nan, PLAYER1_TEAM_ID=nan, PLAYER1_TEAM_CITY=nan, PLAYER1_TEAM_NICKNAME=nan, PLAYER1_TEAM_ABBREVIATION=nan, PERSON2TYPE=0, PLAYER2_ID=0, PLAYER2_NAME=nan, PLAYER2_TEAM_ID=nan, PLAYER2_TEAM_CITY=nan, PLAYER2_TEAM_NICKNAME=nan, PLAYER2_TEAM_ABBREVIATION=nan, PERSON3TYPE=0, PLAYER3_ID=0, PLAYER3_NAME=nan, PLAYER3_TEAM_ID=nan, PLAYER3_TEAM_CITY=nan, PLAYER3_TEAM_NICKNAME=nan, PLAYER3_TEAM_ABBREVIATION=nan)

# %%
jumpball = runthru.__next__()

# %%
jumpball
# Out:
# Pandas(Index=1, GAME_ID=21500001, EVENTNUM=1, EVENTMSGTYPE=10, EVENTMSGACTIONTYPE=0, PERIOD=1, WCTIMESTRING='8:12 PM', PCTIMESTRING='12:00', HOMEDESCRIPTION='Jump Ball Horford vs. Drummond: Tip to Ilyasova', NEUTRALDESCRIPTION=nan, VISITORDESCRIPTION=nan, SCORE=nan, SCOREMARGIN=nan, PERSON1TYPE=4.0, PLAYER1_ID=201143, PLAYER1_NAME='Al Horford', PLAYER1_TEAM_ID=1610612737.0, PLAYER1_TEAM_CITY='Atlanta', PLAYER1_TEAM_NICKNAME='Hawks', PLAYER1_TEAM_ABBREVIATION='ATL', PERSON2TYPE=5, PLAYER2_ID=203083, PLAYER2_NAME='Andre Drummond', PLAYER2_TEAM_ID=1610612765.0, PLAYER2_TEAM_CITY='Detroit', PLAYER2_TEAM_NICKNAME='Pistons', PLAYER2_TEAM_ABBREVIATION='DET', PERSON3TYPE=5, PLAYER3_ID=101141, PLAYER3_NAME='Ersan Ilyasova', PLAYER3_TEAM_ID=1610612765.0, PLAYER3_TEAM_CITY='Detroit', PLAYER3_TEAM_NICKNAME='Pistons', PLAYER3_TEAM_ABBREVIATION='DET')

# %%
jumpball[10]
# Out:
# nan

# %%
jumpball[10] = nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-f0154d9df54c> in <module>()
# ----> 1 jumpball[10] = nan
#
# NameError: name 'nan' is not defined

# %%
pbp = pbp.fillna(value = "")

# %%
pbp
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    21500001         0            12                   0       1
# 1    21500001         1            10                   0       1
# 2    21500001         2             2                  42       1
# 3    21500001         3             4                   0       1
# 4    21500001         4             5                  45       1
# 5    21500001         5             1                  80       1
# 6    21500001         6             1                  80       1
# 7    21500001         7             1                 101       1
# 8    21500001         8             2                   1       1
# 9    21500001         9             4                   0       1
# 10   21500001        10             2                  58       1
# 11   21500001        11             4                   0       1
# 12   21500001        13             1                 105       1
# ...

# %%
jumpball[0]
# Out:
# 1

# %%
pbp[275]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/meileng/anaconda3/lib/python3.4/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 275
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-7d829048e181> in <module>()
# ...

# %%
gameinfo = nbaws.request_stats('all-games', {'Season': 2013})

# %%
dict(gameinfo)
# Out:
# {'list': [{'AST': 28,
#    'BLK': 4,
#    'DREB': 45,
#    'FG3A': 29,
#    'FG3M': 8,
#    'FG3_PCT': 0.276,
#    'FGA': 124,
#    'FGM': 56,
#    'FG_PCT': 0.452,
#    'FTA': 46,
#    'FTM': 27,
#    'FT_PCT': 0.587,
#    'GAME_DATE': '2015-12-18',
#    'GAME_ID': '0021500391',
#    'MATCHUP': 'DET @ CHI',
#    'MIN': 340,
#    'OREB': 19,
#    'PF': 35,
#    'PLUS_MINUS': 3,
#    'PTS': 147,
#    'REB': 64,
#    'SEASON_ID': '22015',
#    'STL': 7,
#    'TEAM_ABBREVIATION': 'DET',
#    'TEAM_ID': 1610612765,
#    'TEAM_NAME': 'Detroit Pistons',
#    'TOV': 11,
#    'VIDEO_AVAILABLE': 1,
#    'WL': 'W'},
#   {'AST': 41,
#    'BLK': 8,
#    'DREB': 38,
#    'FG3A': 28,
#    'FG3M': 13,
#    'FG3_PCT': 0.464,
#    'FGA': 86,
#    'FGM': 56,
#    'FG_PCT': 0.651,
#    'FTA': 23,
#    'FTM': 19,
#    'FT_PCT': 0.826,
#    'GAME_DATE': '2016-04-13',
#    'GAME_ID': '0021501226',
#    'MATCHUP': 'MIN vs. NOP',
#    'MIN': 240,
#    'OREB': 5,
#    'PF': 20,
#    'PLUS_MINUS': 35,
# ...

# %%
gameinfo = dict(gameinfo)

# %%
len(gameinfo)
# Out:
# 1

# %%
len(gameinfo['list'])
# Out:
# 2460

# %%
gameinfo = gameinfo['list']

# %%
import csv

# %%
gameinfo[0]
# Out:
# {'AST': 23,
#  'BLK': 2,
#  'DREB': 29,
#  'FG3A': 24,
#  'FG3M': 13,
#  'FG3_PCT': 0.542,
#  'FGA': 93,
#  'FGM': 48,
#  'FG_PCT': 0.516,
#  'FTA': 28,
#  'FTM': 21,
#  'FT_PCT': 0.75,
#  'GAME_DATE': '2015-04-24',
#  'GAME_ID': '0041400153',
#  'MATCHUP': 'HOU @ DAL',
#  'MIN': 240,
#  'OREB': 17,
#  'PF': 28,
#  'PLUS_MINUS': 2,
#  'PTS': 130,
#  'REB': 46,
#  'SEASON_ID': '42014',
#  'STL': 4,
#  'TEAM_ABBREVIATION': 'HOU',
#  'TEAM_ID': 1610612745,
#  'TEAM_NAME': 'Houston Rockets',
#  'TOV': 14,
#  'VIDEO_AVAILABLE': 1,
#  'WL': 'W'}

# %%
headers = gameinfo[0].keys()

# %%
csvfile = open('games1314reg.csv', 'w')
writer = csv.DictWriter(csvfile, fieldnames = headers)

# %%
writer.writeheader()

# %%
writer.writerows(gameinfo)

# %%
len(gameinfo)
# Out:
# 2460

# %%
gameinfo
# Out:
# [{'AST': 23,
#   'BLK': 2,
#   'DREB': 29,
#   'FG3A': 24,
#   'FG3M': 13,
#   'FG3_PCT': 0.542,
#   'FGA': 93,
#   'FGM': 48,
#   'FG_PCT': 0.516,
#   'FTA': 28,
#   'FTM': 21,
#   'FT_PCT': 0.75,
#   'GAME_DATE': '2015-04-24',
#   'GAME_ID': '0041400153',
#   'MATCHUP': 'HOU @ DAL',
#   'MIN': 240,
#   'OREB': 17,
#   'PF': 28,
#   'PLUS_MINUS': 2,
#   'PTS': 130,
#   'REB': 46,
#   'SEASON_ID': '42014',
#   'STL': 4,
#   'TEAM_ABBREVIATION': 'HOU',
#   'TEAM_ID': 1610612745,
#   'TEAM_NAME': 'Houston Rockets',
#   'TOV': 14,
#   'VIDEO_AVAILABLE': 1,
#   'WL': 'W'},
#  {'AST': 22,
#   'BLK': 10,
#   'DREB': 42,
#   'FG3A': 32,
#   'FG3M': 17,
#   'FG3_PCT': 0.531,
#   'FGA': 76,
#   'FGM': 43,
#   'FG_PCT': 0.566,
#   'FTA': 43,
#   'FTM': 25,
#   'FT_PCT': 0.581,
#   'GAME_DATE': '2015-05-25',
#   'GAME_ID': '0041400314',
#   'MATCHUP': 'HOU vs. GSW',
#   'MIN': 240,
#   'OREB': 4,
#   'PF': 16,
#   'PLUS_MINUS': 13,
#   'PTS': 128,
#   'REB': 46,
#   'SEASON_ID': '42014',
# ...
